# %%
import pickle

# %%
dd_relatives = pickle.load(open('mouse_all_pops.dd_syn_with_outgroup_and_relatives.bpkl', 'rb'))

# %%
dd_no_relatives = pickle.load(open('new_mouse_all_pops.dd_syn.bpkl', 'rb'))

# %%
dd_relatives
# Out:
# {'chr1_3216136': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216259': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216382': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216424': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (1, 15),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216436': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216679': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216742': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (2, 14),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216853': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216913': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421750': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421850': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421856': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421868': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670566': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670638': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670776': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670947': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120055': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120064': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142641': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (14, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142695': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142713': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142737': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142764': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4147827': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (3, 3),
#    'Mmd_IRA': (1, 15),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4147932': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4148730': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 10),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4170334': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197547': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 7),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197583': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (6, 10),
#    'Mmd_GER': (10, 6),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197592': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197604': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4206748': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (4, 12),
#    'Mmd_GER': (7, 9),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (8, 8),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4206766': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226706': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226713': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4228593': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4231137': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4231140': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (11, 9),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4243185': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (2, 18),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245051': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245066': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (4, 12),
#    'Mmd_GER': (8, 8),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (14, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245099': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4261588': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4267484': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4267544': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (13, 3),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4284794': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (9, 7),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344621': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344861': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344918': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345320': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345356': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 7),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345428': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345473': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345598': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (3, 13),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345731': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345794': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345797': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345872': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345917': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (3, 17),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (2, 10),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345920': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346073': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346169': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346207': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346217': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346226': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (14, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346277': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346349': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346370': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346391': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346409': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (2, 10),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346451': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346778': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346826': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346976': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347012': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347096': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347117': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347180': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347246': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (11, 5),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347282': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347351': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347375': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347411': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347453': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347555': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347648': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347677': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347687': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347783': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347885': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347963': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348041': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348062': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348083': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348161': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348164': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348224': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348233': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348281': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348401': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348428': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348512': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348617': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348701': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348818': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348830': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348956': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348977': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349043': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349082': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349154': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349163': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349196': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349220': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349244': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349262': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (8, 12),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (1, 15),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349352': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349490': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349556': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349661': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349682': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349811': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349856': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (8, 4),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349895': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349919': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349949': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349994': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4352232': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352349': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352373': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352394': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352424': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352436': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352465': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4352466': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352574': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352808': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4409173': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491725': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491812': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491842': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
# ...
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150697': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150718': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150784': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150796': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150799': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150802': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150819': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 9),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150820': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150823': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150850': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 9),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150862': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 9),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150877': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150904': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150907': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13152385': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152388': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13152421': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152454': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152854': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 7),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152878': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (5, 15),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13160229': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13162179': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13162224': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13162245': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13166933': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13166939': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13166945': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13167008': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13167017': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13167080': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13174132': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13174163': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13174250': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13174295': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13174436': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13174469': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (7, 9),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13175111': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (10, 6),
#    'Mmd_HEL': (3, 3),
#    'Mmd_IRA': (9, 7),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13177136': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13177163': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13180557': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (8, 8),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13180575': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13180587': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13181271': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184185': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184221': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (8, 8),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184227': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184233': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  ...}

# %%
relatives_keys = dd_relatives.keys()

# %%
no_relatives_keys = dd_no_relatives.keys()

# %%
relatives_keys == no_relatives_keys
# Out:
# True

# %%
for ch_pos in dd_no_relatives.keys():
    dd_no_relatives[ch_pos]['outgroup_allele'] = dd_relatives[ch_pos]['outgroup_allele']
    dd_no_relatives[ch_pos]['outgroup_context'] = dd_relatives[ch_pos]['outgroup_context']

# %%
dd_no_relatives
# Out:
# {'chr1_3216136': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216259': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216382': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216424': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (1, 15),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216436': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216679': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216742': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (2, 14),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216853': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_3216913': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421750': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421850': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421856': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421868': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670566': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670638': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670776': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670947': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120055': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120064': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142641': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142695': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142713': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142737': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142764': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4147827': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (3, 3),
#    'Mmd_IRA': (1, 9),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4147932': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4148730': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (5, 5),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4170334': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197547': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (5, 5),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197583': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (6, 10),
#    'Mmd_GER': (10, 6),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197592': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197604': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4206748': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (4, 12),
#    'Mmd_GER': (7, 9),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (4, 6),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4206766': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226706': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226713': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4228593': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4231137': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4231140': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (11, 9),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4243185': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (2, 18),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245051': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245066': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (4, 12),
#    'Mmd_GER': (8, 8),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245099': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4261588': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4267484': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4267544': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (13, 3),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4284794': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (9, 7),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344621': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344861': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344918': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345320': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345356': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345428': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345473': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345598': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (3, 13),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345731': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345794': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345797': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345872': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345917': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (3, 17),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (2, 10),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345920': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346073': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346169': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346207': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346217': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346226': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346277': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346349': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346370': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346391': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346409': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (2, 10),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346451': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346778': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346826': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346976': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347012': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347096': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347117': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347180': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347246': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (11, 5),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347282': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347351': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347375': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347411': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347453': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347555': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347648': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347677': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347687': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347783': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347885': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347963': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348041': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348062': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348083': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348161': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348164': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348224': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348233': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348281': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348401': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348428': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348512': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348617': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348701': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348818': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348830': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348956': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348977': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349043': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349082': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349154': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349163': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349196': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349220': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349244': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349262': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (8, 12),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (1, 9),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349352': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349490': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349556': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349661': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349682': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349811': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349856': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (8, 4),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349895': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349919': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4349949': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4349994': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4352232': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352349': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352373': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352394': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352424': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352436': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352465': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4352466': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352574': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4352808': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4409173': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491725': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491812': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491842': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4491943': {'segregating': ('G', 'A'),
#   'context': '-G-',
# ...
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150697': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150718': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150784': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150796': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150799': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150802': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150819': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 4),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150820': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150823': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150850': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150862': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 4),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13150877': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150904': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13150907': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13152385': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152388': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13152421': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152454': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152854': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13152878': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (5, 15),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13160229': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13162179': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13162224': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13162245': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13166933': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13166939': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13166945': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13167008': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13167017': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13167080': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13174132': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13174163': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13174250': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13174295': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13174436': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13174469': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (7, 9),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13175111': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (10, 6),
#    'Mmd_HEL': (3, 3),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13177136': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13177163': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13180557': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (8, 8),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_13180575': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13180587': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13181271': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184185': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184221': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (8, 8),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184227': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_13184233': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  ...}

# %%
pick = open('mouse_all_pops_no_relatives_yes_outgroup.dd_syn.bpkl','wb')
pickle.dump(dd_no_relatives, pick, 2)

# %%
import dadi

# %%
pop_ids = ['Mmd_FRA', 'Mmd_IRA']
ns = [16, 10]
fs = dadi.Spectrum.from_data_dict(dd_no_relatives, pop_ids, ns)
fs.to_file('IRA_FRA_syn_unfolded.fs')

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1, figsize = (10,6))
fig.clear()
ax = fig.add_subplot(2, 3, 1)
ax.set_title('Original SFS')
dadi.Plotting.plot_single_2d_sfs(fs, ax = ax)
