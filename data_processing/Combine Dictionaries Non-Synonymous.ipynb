# %%
import pickle

# %%
dd_relatives = pickle.load(open('mouse_all_pops.dd_nsyn_with_outgroup_and_relatives.bpkl', 'rb'))

# %%
dd_no_relatives = pickle.load(open('mouse_all_pops.dd_nsyn.bpkl', 'rb'))

# %%
dd_relatives
# Out:
# {'chr1_3216083': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216380': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216886': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421849': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670816': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120012': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120045': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142689': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142696': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142700': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142748': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (14, 2),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4147850': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4147904': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4148621': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4148671': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4163916': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170278': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170324': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (13, 3),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170329': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170382': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (12, 4),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4170395': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (5, 11),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197545': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (12, 8),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 7),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197548': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197549': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (3, 3),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197554': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4197603': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4206732': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226660': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226721': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4228606': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (5, 15),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4231069': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (9, 11),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4231108': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4231136': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (11, 9),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4243434': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4243548': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245046': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (3, 17),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 10),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245053': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245077': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4267600': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4267614': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (9, 7),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (10, 6),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4284779': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4292986': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (11, 5),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4292989': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4311313': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4311371': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344635': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (10, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344651': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 6),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344653': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344686': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344704': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344820': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 6),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344853': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344862': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344904': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (8, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344914': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344992': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345007': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345084': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345100': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345117': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 6),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345127': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345132': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345147': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345307': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345340': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345355': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345378': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345409': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345456': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345483': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345637': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345666': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345702': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345703': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345730': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (8, 4),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (13, 3),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345744': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345775': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345849': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345902': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345969': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345985': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346098': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346137': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346143': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346152': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346161': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346164': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346204': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346210': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346243': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346287': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346359': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346389': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346434': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346435': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346436': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346480': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346497': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346509': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346515': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346544': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (12, 8),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346546': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346562': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346693': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346741': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346743': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346864': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346902': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (9, 11),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346914': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346918': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346951': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346998': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347011': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347035': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347070': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347074': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347080': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347161': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347163': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347208': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347214': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347245': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347247': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347261': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347269': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347281': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (3, 13),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347461': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347502': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (13, 3),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347511': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347562': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347605': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347612': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347632': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347647': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347782': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347956': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347959': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348018': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348030': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348067': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348090': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348093': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
# ...
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20520289': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522675': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (15, 1),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522771': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522873': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20522874': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522882': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522906': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522913': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522952': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (13, 3),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522979': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (3, 13),
#    'Mmd_HEL': (0, 6),
#    'Mmd_IRA': (0, 16),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523005': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523048': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (8, 12),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (12, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523080': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523090': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523125': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (10, 10),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (12, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523186': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523209': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523255': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (13, 3),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523291': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523342': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523353': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523381': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523386': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (12, 8),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523398': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523440': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523669': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (7, 9),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523749': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523787': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523795': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523851': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (12, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523867': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523902': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523953': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523957': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523992': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (15, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524008': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524089': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524097': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (3, 17),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (12, 4),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20524103': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524117': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524130': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (13, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524170': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524202': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524208': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524224': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524238': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524248': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (16, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  ...}

# %%
relatives_keys = dd_relatives.keys()

# %%
no_relatives_keys = dd_no_relatives.keys()

# %%
relatives_keys == no_relatives_keys
# Out:
# True

# %%
for ch_pos in dd_no_relatives.keys():
    dd_no_relatives[ch_pos]['outgroup_allele'] = dd_relatives[ch_pos]['outgroup_allele']
    dd_no_relatives[ch_pos]['outgroup_context'] = dd_relatives[ch_pos]['outgroup_context']

# %%
dd_no_relatives
# Out:
# {'chr1_3216083': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216380': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3216886': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3421849': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (12, 4),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_3670816': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120012': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (3, 13),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4120045': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142689': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142696': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142700': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4142748': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (14, 2),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4147850': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4147904': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4148621': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4148671': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4163916': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170278': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170324': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (13, 3),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170329': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4170382': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4170395': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (3, 7),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197545': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (12, 8),
#    'Mmd_FRA': (13, 3),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (5, 5),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197548': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197549': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (3, 3),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4197554': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4197603': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (6, 4),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4206732': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226660': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4226721': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4228606': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (5, 15),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4231069': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (9, 11),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4231108': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4231136': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (11, 9),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4243434': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4243548': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245046': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (3, 17),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 10),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245053': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4245077': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4267600': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4267614': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (9, 7),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (7, 3),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4284779': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4292986': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (1, 15),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (5, 5),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4292989': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4311313': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4311371': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344635': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (10, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344651': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344653': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344686': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344704': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344820': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (1, 19),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (5, 5),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344853': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344862': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4344904': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (8, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344914': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4344992': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (14, 2),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345007': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345084': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345100': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345117': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345127': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345132': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345147': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345307': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345340': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345355': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345378': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345409': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345456': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345483': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345637': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345666': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345702': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345703': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345730': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (8, 4),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (13, 3),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345744': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345775': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345849': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345902': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4345969': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4345985': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346098': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (10, 6),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346137': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (15, 5),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346143': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346152': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346161': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346164': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346204': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346210': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346243': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346287': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346359': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346389': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346434': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346435': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346436': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346480': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346497': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346509': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346515': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346544': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (12, 8),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346546': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (0, 16),
#    'Mmd_GER': (5, 11),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346562': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346693': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346741': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346743': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346864': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346902': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (9, 11),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346914': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346918': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4346951': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (13, 7),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4346998': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347011': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (9, 7),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347035': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347070': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (6, 14),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347074': {'segregating': ('T', 'G'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (4, 16),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347080': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347161': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347163': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347208': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347214': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347245': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (9, 3),
#    'Mmm_CZE': (8, 8),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347247': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (15, 1),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347261': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347269': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347281': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (2, 8),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (14, 2),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347461': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347502': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (13, 3),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347511': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (6, 10),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4347562': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347605': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347612': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347632': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347647': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347782': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347956': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4347959': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348018': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_4348030': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348067': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (11, 1),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348090': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (3, 9),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348093': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (14, 6),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (1, 11),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (7, 9),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_4348149': {'segregating': ('C', 'A'),
#   'context': '-C-',
# ...
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20520289': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522675': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (15, 1),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522771': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522873': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20522874': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522882': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522906': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (10, 2),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (12, 4),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522913': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522952': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (13, 3),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20522979': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (0, 20),
#    'Mmd_FRA': (3, 13),
#    'Mmd_GER': (3, 13),
#    'Mmd_HEL': (0, 6),
#    'Mmd_IRA': (0, 10),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523005': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523048': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (8, 12),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523080': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523090': {'segregating': ('T', 'C'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (15, 1),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523125': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (10, 10),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523186': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523209': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523255': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (13, 3),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523291': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523342': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523353': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523381': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523386': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (12, 8),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20523398': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523440': {'segregating': ('A', 'T'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523669': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (7, 9),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (5, 1),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523749': {'segregating': ('T', 'A'),
#   'context': '-T-',
#   'outgroup_allele': 'T',
#   'outgroup_context': '-T-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523787': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523795': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523851': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (12, 4),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523867': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523902': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523953': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523957': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20523992': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524008': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524089': {'segregating': ('C', 'A'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524097': {'segregating': ('A', 'G'),
#   'context': '-A-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (3, 17),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (11, 5),
#    'Mmd_HEL': (2, 4),
#    'Mmd_IRA': (8, 2),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (0, 16),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (0, 16)}},
#  'chr1_20524103': {'segregating': ('G', 'A'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (16, 4),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524117': {'segregating': ('C', 'G'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (0, 12),
#    'Mmm_CZE': (4, 12),
#    'Mmm_KAZ': (0, 16),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524130': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524170': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (13, 3),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524202': {'segregating': ('A', 'C'),
#   'context': '-A-',
#   'outgroup_allele': 'A',
#   'outgroup_context': '-A-',
#   'calls': {'Mmc_CAST': (18, 2),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524208': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (14, 2),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524224': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524238': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (19, 1),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  'chr1_20524248': {'segregating': ('G', 'T'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (17, 3),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)}},
#  ...}

# %%
pick = open('new_mouse_all_pops.dd_nsyn.bpkl','wb')
pickle.dump(dd_no_relatives, pick, 2)

# %%
import dadi

# %%
pop_ids = ['Mmd_FRA', 'Mmd_IRA']
ns = [16, 10]
fs = dadi.Spectrum.from_data_dict(dd_no_relatives, pop_ids, ns)
fs.to_file('IRA_FRA_nsyn_unfolded.fs')

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1, figsize = (10,6))
fig.clear()
ax = fig.add_subplot(2, 3, 1)
ax.set_title('Original SFS')
dadi.Plotting.plot_single_2d_sfs(fs, ax = ax)
