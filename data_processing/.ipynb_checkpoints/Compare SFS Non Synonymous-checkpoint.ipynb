# %%
import dadi

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1, figsize = (10,6))
fig.clear()

ax = fig.add_subplot(2, 3, 1)
ax.set_title('New Non Synonymous SFS')
dadi.Plotting.plot_single_2d_sfs(dadi.Spectrum.from_file('IRA_FRA_nsyn_unfolded.fs'), ax = ax)

ax = fig.add_subplot(2, 3, 2)
ax.set_title('Old Non Synonymous SFS')
dadi.Plotting.plot_single_2d_sfs(dadi.Spectrum.from_file('/Users/oliviafernflores/Documents/2D_demographics_DFE/MMD_2D_Project/FRA_IRA/IRA_FRA_nsyn_unfolded.fs'), ax = ax)

residuals = (dadi.Spectrum.from_file('/Users/oliviafernflores/Documents/2D_demographics_DFE/MMD_2D_Project/FRA_IRA/IRA_FRA_nsyn_unfolded.fs')) - (dadi.Spectrum.from_file('IRA_FRA_nsyn_unfolded.fs'))

ax = fig.add_subplot(2, 3, 3)
ax.set_title('Difference in SFS (old - new)')
dadi.Plotting.plot_2d_resid(residuals, resid_range = 3, ax = ax)

fig.tight_layout()

plt.savefig('IRA_FRA_nsyn_fs_comparison.png')

# %%
fig = plt.figure(1, figsize = (10,6))
fig.clear()

ax = fig.add_subplot(2, 3, 1)
ax.set_title('New Non Synonymous SFS')
dadi.Plotting.plot_single_2d_sfs(dadi.Spectrum.from_file('FRA_GER_nsyn_unfolded.fs'), ax = ax)

ax = fig.add_subplot(2, 3, 2)
ax.set_title('Old Non Synonymous SFS')
dadi.Plotting.plot_single_2d_sfs(dadi.Spectrum.from_file('/Users/oliviafernflores/Documents/2D_demographics_DFE/MMD_2D_Project/GER_FRA/FRA_GER_nsyn_unfolded.fs'), ax = ax)

residuals = (dadi.Spectrum.from_file('/Users/oliviafernflores/Documents/2D_demographics_DFE/MMD_2D_Project/GER_FRA/FRA_GER_nsyn_unfolded.fs')) - (dadi.Spectrum.from_file('FRA_GER_nsyn_unfolded.fs'))

ax = fig.add_subplot(2, 3, 3)
ax.set_title('Difference in SFS (old - new)')
dadi.Plotting.plot_2d_resid(residuals, resid_range = 3, ax = ax)

fig.tight_layout()

plt.savefig('FRA_GER_nsyn_fs_comparison.png')

# %%
fig = plt.figure(1, figsize = (10,6))
fig.clear()

ax = fig.add_subplot(2, 3, 1)
ax.set_title('New Non Synonymous SFS')
dadi.Plotting.plot_single_2d_sfs(dadi.Spectrum.from_file('GER_HEL_nsyn_unfolded.fs'), ax = ax)

ax = fig.add_subplot(2, 3, 2)
ax.set_title('Old Non Synonymous SFS')
dadi.Plotting.plot_single_2d_sfs(dadi.Spectrum.from_file('/Users/oliviafernflores/Documents/2D_demographics_DFE/MMD_2D_Project/HEL_GER/GER_HEL_nsyn_unfolded.fs'), ax = ax)

residuals = (dadi.Spectrum.from_file('/Users/oliviafernflores/Documents/2D_demographics_DFE/MMD_2D_Project/HEL_GER/GER_HEL_nsyn_unfolded.fs')) - (dadi.Spectrum.from_file('GER_HEL_nsyn_unfolded.fs'))

ax = fig.add_subplot(2, 3, 3)
ax.set_title('Difference in SFS (old - new)')
dadi.Plotting.plot_2d_resid(residuals, resid_range = 3, ax = ax)

fig.tight_layout()

plt.savefig('GER_HEL_nsyn_fs_comparison.png')
