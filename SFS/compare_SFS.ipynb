# %%
import dadi

# %%
IRA_FRA_syn_new = dadi.Spectrum.from_file("IRA_FRA_syn_unfolded.fs")

# %%
IRA_FRA_syn_old = dadi.Spectrum.from_file("/Users/olivia/Documents/2D_demographics_DFE/MMD_2D_Project/old_results/FRA_IRA/IRA_FRA_syn_unfolded.fs")

# %%
dadi.Plotting.plot_2d_comp_multinom(IRA_FRA_syn_new, IRA_FRA_syn_old, vmin=1, pop_ids =('Mmd_FRA','Mmd_IRA'), show=False)

# %%
IRA_FRA_nsyn_new = dadi.Spectrum.from_file("IRA_FRA_nsyn_unfolded.fs")

# %%
IRA_FRA_nsyn_old = dadi.Spectrum.from_file("/Users/olivia/Documents/2D_demographics_DFE/MMD_2D_Project/old_results/FRA_IRA/IRA_FRA_nsyn_unfolded.fs")

# %%
dadi.Plotting.plot_2d_comp_multinom(IRA_FRA_nsyn_new, IRA_FRA_nsyn_old, vmin=1, pop_ids =('Mmd_FRA','Mmd_IRA'), show=False)
