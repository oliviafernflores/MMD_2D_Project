# %%
import pickle

# %%
dict = pickle.load(open('/Users/olivia/Documents/2D_demographics_DFE/MMD_2D_Project/gene_ontology/mus_all_pops_nsyn_with_ancestral_and_GO_terms.pkl', 'rb'))

# %%
dict
# Out:
# {'chr1_3216083': {'segregating': ('C', 'T'),
#   'context': '-C-',
#   'outgroup_allele': 'C',
#   'outgroup_context': '-C-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (15, 1),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (10, 0),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)},
#   'GO_terms': []},
#  'chr1_3216380': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
#    'Mmd_HEL': (6, 0),
#    'Mmd_IRA': (9, 1),
#    'Mmm_AFG': (12, 0),
#    'Mmm_CZE': (16, 0),
#    'Mmm_KAZ': (16, 0),
#    'Ms_SPRE': (16, 0)},
#   'GO_terms': []},
#  'chr1_3216886': {'segregating': ('G', 'C'),
#   'context': '-G-',
#   'outgroup_allele': 'G',
#   'outgroup_context': '-G-',
#   'calls': {'Mmc_CAST': (20, 0),
#    'Mmd_FRA': (16, 0),
#    'Mmd_GER': (16, 0),
# ...

# %%
matches = []

# %%
for key, value in dict.items():
    matches.append(dict[key]['GO_terms'])

# %%
matches
# Out:
# [[],
#  [],
#  [],
#  ['GO:0016020',
#   'GO:0071944',
#   'GO:0005886',
#   'GO:0005886',
#   'GO:0005886',
#   'GO:0006915',
#   'GO:0017128',
#   'GO:0043652',
#   'GO:0070782',
#   'GO:1902742',
#   'GO:0070782'],
#  ['GO:0016020',
#   'GO:0071944',
#   'GO:0005886',
#   'GO:0005886',
#   'GO:0005886',
#   'GO:0006915',
#   'GO:0017128',
#   'GO:0043652',
#   'GO:0070782',
#   'GO:1902742',
#   'GO:0070782'],
#  ['GO:0005515',
#   'GO:0035556',
#   'GO:0035556',
#   'GO:0060041',
#   'GO:0042995',
#   'GO:0005737',
#   'GO:0008017',
#   'GO:0030030',
#   'GO:0005856',
#   'GO:0050896',
#   'GO:0005929',
#   'GO:0005930',
#   'GO:0007601',
#   'GO:0001750',
#   'GO:0001750',
#   'GO:0001917',
#   'GO:0043005',
#   'GO:0005930',
#   'GO:0001917',
#   'GO:0032391',
#   'GO:0032391',
#   'GO:0005929',
#   'GO:0035082',
#   'GO:0035082',
#   'GO:0042461',
#   'GO:1902857',
#   'GO:1902857',
#   'GO:0046549',
#   'GO:0071482',
#   'GO:0045494',
#   'GO:0060041',
#   'GO:0060042',
# ...

# %%
count = 0

# %%
for lst in matches:
    if 'GO:0045063' in lst:
        count += 1

# %%
count
# Out:
# 57
